# %% [markdown]
# <a href="https://colab.research.google.com/github/kkishor714/My-First-Repository/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_excel("data.xlsx")

# %%
df.head()
# Out:
#    client_id region                     friendly_id  \
# 0  richemont     ID  RIC-MP-TOK-20250526-1430-HQGI0
# 1  richemont     ID  RIC-MP-TOK-20250526-1048-A0B7O
# 2  richemont     ID  RIC-MP-TOK-20250526-0901-0UCIF
# 3  richemont     ID  RIC-MP-TOK-20250527-0813-OZUNY
# 4  richemont     ID  RIC-MP-TOK-20250526-0930-RK2A2
#
#                                         scraped_urls
# 0  https://www.tokopedia.com/akh-autowatchii/akh-...
# 1  https://www.tokopedia.com/akh-autowatchii/akh-...
# 2  https://www.tokopedia.com/akh-autowatchii/akh-...
# 3  https://www.tokopedia.com/akh-autowatchii/akh-...
# 4  https://www.tokopedia.com/akh-autowatchii/akh-...

# %%
df.tail()
# Out:
#      client_id region                     friendly_id  \
# 727  richemont     ID  RIC-MP-TOK-20250327-0728-FPLS4
# 728  richemont     ID  RIC-MP-TOK-20250326-2028-Q2M2L
# 729  richemont     ID  RIC-MP-TOK-20250325-1149-FGV89
# 730  richemont     ID  RIC-MP-TOK-20250325-1051-4HPEF
# 731  richemont     ID  RIC-MP-TOK-20250320-0719-X3525
#
#                                           scraped_urls
# 727  https://www.tokopedia.com/akh-autowatchii/akh-...
# 728  https://www.tokopedia.com/akh-autowatchii/akh-...
# 729  https://www.tokopedia.com/akh-autowatchii/akh-...
# 730  https://www.tokopedia.com/numberonewatch/no1wa...
# 731  https://www.tokopedia.com/akh-autowatchii/akh-...

# %%
df.shape
# Out:
# (732, 4)

# %%
df.columns
# Out:
# Index(['client_id', 'region', 'friendly_id', 'scraped_urls'], dtype='object')
